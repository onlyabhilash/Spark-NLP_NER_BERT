# %% [markdown]
# <a href="https://colab.research.google.com/github/onlyabhilash/Spark-NLP_NER_BERT/blob/main/Spark_NER_Bert_3_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get --purge remove cuda nvidia* libnvidia-*
# !dpkg -l | grep cuda- | awk '{print $2}' | xargs -n1 dpkg --purge
# !apt-get remove cuda-*
# !apt autoremove
# !apt-get update
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Note, selecting 'nvidia-kernel-common-418-server' for glob 'nvidia*'
# Note, selecting 'nvidia-325-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-346-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-binary' for glob 'nvidia*'
# Note, selecting 'nvidia-331-dev' for glob 'nvidia*'
# Note, selecting 'nvidia-304-updates-dev' for glob 'nvidia*'
# Note, selecting 'nvidia-compute-utils-418-server' for glob 'nvidia*'
# Note, selecting 'nvidia-384-dev' for glob 'nvidia*'
# Note, selecting 'nvidia-libopencl1-346-updates' for glob 'nvidia*'
# Note, selecting 'nvidia-driver-440-server' for glob 'nvidia*'
# Note, selecting 'nvidia-340-updates-uvm' for glob 'nvidia*'
# Note, selecting 'nvidia-dkms-450-server' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-common' for glob 'nvidia*'
# Note, selecting 'nvidia-kernel-source-440-server' for glob 'nvidia*'
# ...

# %%
# !nvidia-smi
# Out:
# Fri May 21 06:48:10 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   43C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !wget https://developer.nvidia.com/compute/cuda/10.0/Prod/local_installers/cuda-repo-ubuntu1804-10-0-local-10.0.130-410.48_1.0-1_amd64 -O cuda-repo-ubuntu1804-10-0-local-10.0.130-410.48_1.0-1_amd64.deb
# Out:
# --2021-05-21 06:48:10--  https://developer.nvidia.com/compute/cuda/10.0/Prod/local_installers/cuda-repo-ubuntu1804-10-0-local-10.0.130-410.48_1.0-1_amd64
# Resolving developer.nvidia.com (developer.nvidia.com)... 152.199.16.29
# Connecting to developer.nvidia.com (developer.nvidia.com)|152.199.16.29|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://developer.nvidia.com/compute/cuda/10.0/prod/local_installers/cuda-repo-ubuntu1804-10-0-local-10.0.130-410.48_1.0-1_amd64 [following]
# --2021-05-21 06:48:11--  https://developer.nvidia.com/compute/cuda/10.0/prod/local_installers/cuda-repo-ubuntu1804-10-0-local-10.0.130-410.48_1.0-1_amd64
# Reusing existing connection to developer.nvidia.com:443.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !dpkg -i cuda-repo-ubuntu1804-10-0-local-10.0.130-410.48_1.0-1_amd64.deb
# !apt-key add /var/cuda-repo-10-0-local/7fa2af80.pub
# !apt-get update
# !apt-get install cuda-10.0
# Out:
# Selecting previously unselected package cuda-repo-ubuntu1804-10-0-local-10.0.130-410.48.
# (Reading database ... 124278 files and directories currently installed.)
# Preparing to unpack cuda-repo-ubuntu1804-10-0-local-10.0.130-410.48_1.0-1_amd64.deb ...
# Unpacking cuda-repo-ubuntu1804-10-0-local-10.0.130-410.48 (1.0-1) ...
# Setting up cuda-repo-ubuntu1804-10-0-local-10.0.130-410.48 (1.0-1) ...
# gpg: can't open '/var/cuda-repo-10-0-local/7fa2af80.pub': No such file or directory
# Get:1 file:/var/cuda-repo-10-0-local-10.0.130-410.48  InRelease
# Ign:1 file:/var/cuda-repo-10-0-local-10.0.130-410.48  InRelease
# Get:2 file:/var/cuda-repo-10-0-local-10.0.130-410.48  Release [574 B]
# Get:2 file:/var/cuda-repo-10-0-local-10.0.130-410.48  Release [574 B]
# Get:3 file:/var/cuda-repo-10-0-local-10.0.130-410.48  Release.gpg [833 B]
# Get:3 file:/var/cuda-repo-10-0-local-10.0.130-410.48  Release.gpg [833 B]
# Hit:4 http://archive.ubuntu.com/ubuntu bionic InRelease
# ...

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2018 NVIDIA Corporation
# Built on Sat_Aug_25_21:08:01_CDT_2018
# Cuda compilation tools, release 10.0, V10.0.130

# %%
# !pip install git+git://github.com/andreinechaev/nvcc4jupyter.git
# Out:
# ...
#   Cloning git://github.com/andreinechaev/nvcc4jupyter.git to /tmp/pip-req-build-a5komwy1
#   Running command git clone -q git://github.com/andreinechaev/nvcc4jupyter.git /tmp/pip-req-build-a5komwy1
# ...
#   Created wheel for NVCCPlugin: filename=NVCCPlugin-0.0.2-cp37-none-any.whl size=4307 sha256=31b8b0513d7c6a3d3eb7ab87f45e41bfc3d54479398d6f2cb35280e2b470a258
#   Stored in directory: /tmp/pip-ephem-wheel-cache-u8ky151m/wheels/10/c2/05/ca241da37bff77d60d31a9174f988109c61ba989e4d4650516
# Successfully built NVCCPlugin

# %%
# %load_ext nvcc_plugin
# Out:
# directory /content/src already exists
# Out bin /content/result.out

# %%
# %%cu
# #include <stdio.h>
# #include <stdlib.h>
# __global__ void add(int *a, int *b, int *c) {
# *c = *a + *b;
# }
# int main() {
# int a, b, c;
# // host copies of variables a, b & c
# int *d_a, *d_b, *d_c;
# // device copies of variables a, b & c
# int size = sizeof(int);
# // Allocate space for device copies of a, b, c
# cudaMalloc((void **)&d_a, size);
# cudaMalloc((void **)&d_b, size);
# cudaMalloc((void **)&d_c, size);
# // Setup input values
# c = 0;
# a = 3;
# b = 5;
# // Copy inputs to device
# cudaMemcpy(d_a, &a, size, cudaMemcpyHostToDevice);
#   cudaMemcpy(d_b, &b, size, cudaMemcpyHostToDevice);
# // Launch add() kernel on GPU
# add<<<1,1>>>(d_a, d_b, d_c);
# // Copy result back to host
# cudaError err = cudaMemcpy(&c, d_c, size, cudaMemcpyDeviceToHost);
#   if(err!=cudaSuccess) {
#       printf("CUDA error copying to Host: %s\n", cudaGetErrorString(err));
#   }
# printf("result is %d\n",c);
# // Cleanup
# cudaFree(d_a);
# cudaFree(d_b);
# cudaFree(d_c);
# return 0;
# }
# Out:
# result is 8

# %%
import os

# Install java
! apt-get update -qq
! apt-get install -y openjdk-8-jdk-headless -qq > /dev/null

os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["PATH"] = os.environ["JAVA_HOME"] + "/bin:" + os.environ["PATH"]
! java -version

# Install pyspark
#! pip install --ignore-installed pyspark==2.4.4
! pip install --ignore-installed pyspark==3.1.1
# Install Spark NLP
#! pip install --ignore-installed spark-nlp==2.7.3
! pip install --ignore-installed spark-nlp==3.0.3
# Out:
# openjdk version "1.8.0_292"
# OpenJDK Runtime Environment (build 1.8.0_292-8u292-b10-0ubuntu1~18.04-b10)
# OpenJDK 64-Bit Server VM (build 25.292-b10, mixed mode)
# Processing /root/.cache/pip/wheels/0b/90/c0/01de724414ef122bd05f056541fb6a0ecf47c7ca655f8b3c0f/pyspark-3.1.1-py2.py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/9e/b6/6a4fb90cd235dc8e265a6a2067f2a2c99f0d91787f06aca4bcf7c23f3f80/py4j-0.10.9-py2.py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/6c/35/3d06b93fefdeab0f6f544b1fc48e5e49c049697c38611ef870383031380b/spark_nlp-3.0.3-py2.py3-none-any.whl
# ...

# %%
#Import Packages
from pyspark.sql import SparkSession
from pyspark.ml import Pipeline

import sparknlp
from sparknlp.annotator import *
from sparknlp.common import *
from sparknlp.base import *
from sklearn.metrics import classification_report

# %%
def start(gpu=True):
    builder = SparkSession.builder \
        .appName("Spark NLP") \
        .master("local[4]") \
        .config("spark.driver.memory", "16G") \
        .config("spark.driver.maxResultSize", "0") \
        .config("spark.serializer", "org.apache.spark.serializer.KryoSerializer")\
        .config("spark.kryoserializer.buffer.max", "2000M")
    if gpu:
        builder.config("spark.jars.packages", "com.johnsnowlabs.nlp:spark-nlp_2.12:3.0.3")
    else:
        builder.config("spark.jars.packages", "com.johnsnowlabs.nlp:spark-nlp_2.12:3.0.3")

    return builder.getOrCreate()

  
spark = start(gpu=True)

# %%
# !cp /content/drive/MyDrive/Priya/Spark-NLP/bio-tag-5000.csv /content

# %%
# !cp /content/drive/MyDrive/Priya/Spark-NLP/bio_tag18_2200.csv /content

# %%
#Import Dataset
import pandas as pd
df = pd.read_csv('/content/bio_tag18_2200.csv',sep='*',encoding="utf-8")
df.tail()
# Out:
#          Sentence #        Word  POS Tag
# 2316238        2220          14   CD   O
# 2316239        2220         tsp   NN   O
# 2316240        2220  strawberry   NN   O
# 2316241        2220         jam   NN   O
# 2316242        2220  directions  NNS   O

# %%
conll_lines="-DOCSTART- -X- -X- -O-\n\n"
save=0
file_loc = '/content/train.txt'
for sent, token, pos, label in zip(df['Sentence #'],df['Word'],df['POS'],df['Tag']): 
    
# If the sentence ID has changed, that means we are starting a new sentence. We have to add an empty line.
    
    if save!=sent:
        conll_lines+='\n'
    
# Save the conll line
    
    conll_lines += "{} {} {} {}\n".format(token,pos,pos,label)
    
    save=sent
    

# Now print all of the lines to a text file

with open(file_loc,'w') as txtfile:
        
    for line in conll_lines:
        txtfile.write(line)

txtfile.close()

with open(file_loc,'r') as f:
    lines=f.readlines()[0:10]
f.close()
lines
# Out:
# ['-DOCSTART- -X- -X- -O-\n',
#  '\n',
#  '\n',
#  'listed VBN VBN O\n',
#  'on IN IN O\n',
#  'your PRP$ PRP$ O\n',
#  'website NN NN O\n',
#  'before IN IN O\n',
#  'you PRP PRP O\n',
#  'send NN NN O\n']

# %%
# Creating CoNLL(Conference on Natural Language Learning) files
from sparknlp.training import CoNLL

train_data = CoNLL().readDataset(spark, '/content/train.txt')
train_data.show(5)
# Out:
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |                text|            document|            sentence|               token|                 pos|               label|
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |listed on your we...|[{document, 0, 22...|[{document, 0, 22...|[{token, 0, 5, li...|[{pos, 0, 5, VBN,...|[{named_entity, 0...|
# |in the email the ...|[{document, 0, 33...|[{document, 0, 33...|[{token, 0, 1, in...|[{pos, 0, 1, IN, ...|[{named_entity, 0...|
# |removed for no re...|[{document, 0, 29...|[{document, 0, 29...|[{token, 0, 6, re...|[{pos, 0, 6, VBN,...|[{named_entity, 0...|
# |your birth certif...|[{document, 0, 35...|[{document, 0, 35...|[{token, 0, 3, yo...|[{pos, 0, 3, PRP$...|[{named_entity, 0...|
# ...

# %%
from pyspark.sql import functions as F
#train_data, test_data = data.randomSplit([0.8, 0.2], seed = 100)
train_data.select(F.explode(F.arrays_zip('token.result','label.result')).alias("cols"))\
.select(F.expr("cols['0']").alias("token"),
        F.expr("cols['1']").alias("ground_truth")).groupBy('ground_truth').count()\
        .orderBy('count', ascending=False).show(40,truncate=False)
# Out:
# +-------------------------------+-------+
# |ground_truth                   |count  |
# +-------------------------------+-------+
# |O                              |2105752|
# |I-mini_miranda                 |15159  |
# |I-identify_original_creditor   |14910  |
# |I-call_back                    |13234  |
# |I-call_recording_disclosure    |12188  |
# |I-voicemail_script             |10990  |
# |I-account_balance_informed     |10473  |
# |I-do_not_contact               |9708   |
# |I-verify_social                |9692   |
# |I-identify_firm                |9028   |
# |I-wrong_number                 |8942   |
# |I-verfiy_full_name             |8854   |
# |I-ivr                          |8528   |
# |I-tcpa_disclosure              |8402   |
# |I-voicemail                    |7984   |
# |I-verify_dob                   |7875   |
# |I-verify_address               |7424   |
# |I-debt_settlement_attorney_firm|6652   |
# |B-verify_dob                   |2331   |
# ...

# %%
train_data.count()
# Out:
# 89901

# %%
# !cp -r /content/drive/MyDrive/Priya/Spark-NLP/tf-graph /content/

# %%
# !rm -rf /conent

# %%
# !cp -r /root/cache_pretrained/albert_base_uncased_en_2.5.0_2.4_1588073363475 /content/drive/MyDrive/Priya/Spark-NLP/

# %%
! rm -rf /content/bert_base_cased_en_2.6.0_2.4_1598340336670

# %%
# bert_annotator = BertEmbeddings.pretrained('small_bert_L12_128', 'en') \
#  .setInputCols(["sentence",'token'])\
#  .setOutputCol("bert-embedding")\
#  .setMaxSentenceLength(512)\
# Out:
# small_bert_L12_128 download started this may take some time.
# Approximate size to download 23.4 MB
# [OK!]

# %%
# albert = AlbertEmbeddings.pretrained() \
#         .setInputCols("sentence", "token") \
#         .setOutputCol("albert")

# %%
albert = AlbertEmbeddings.load('/content/drive/MyDrive/Priya/Spark-NLP/albert_base_uncased_en_2.5.0_2.4_1588073363475') \
        .setInputCols("sentence", "token") \
        .setOutputCol("albert")

# %%
#train_data = albert.transform(train_data)

# %%
# %%time
#train_data.write.parquet('/content/drive/MyDrive/Priya/Spark-NLP/albert_ner_dl_train.parquet')
# Out:
# CPU times: user 34.4 s, sys: 3.93 s, total: 38.3 s
# Wall time: 1h 34min 47s

# %%
# !cp -r /content/drive/MyDrive/Priya/Spark-NLP/tf-graph /content/

# %%
nerTagger = NerDLApproach()\
        .setInputCols(["sentence", "token","albert"])\
        .setLabelColumn("label")\
        .setOutputCol("ner")\
        .setMaxEpochs(15)\
        .setLr(0.002)\
        .setPo(0.005)\
        .setDropout(0.5)\
        .setBatchSize(32)\
        .setRandomSeed(0)\
        .setVerbose(1)\
        .setValidationSplit(0.1)\
        .setUseContrib(True)\
        .setEvaluationLogExtended(True) \
        .setEnableOutputLogs(True)\
        .setIncludeConfidence(True)\
        .setOutputLogsPath('/content/drive/MyDrive/Priya/Spark-NLP/albert_ner_logs_3.0')\
        .setEnableMemoryOptimizer(True)\
        .setGraphFolder("/content/tf-graph")
ner_pipeline_bert = Pipeline(stages=[
    nerTagger
])

# %%
train_data = spark.read.parquet('/content/drive/MyDrive/Priya/Spark-NLP/albert_ner_dl_train.parquet')

# %%
# %%time
ner_model_bert = ner_pipeline_bert.fit(train_data)

# %%
# !cp -r /content/drive/MyDrive/Priya/Spark-NLP/small_bert_L12_128_en_2.6.0_2.4_1598344378220 /content/

# %%
bert_annotator = BertEmbeddings.load('/content/drive/MyDrive/Priya/Spark-NLP/small_bert_L12_128_en_2.6.0_2.4_1598344378220') \
 .setInputCols(["sentence",'token'])\
 .setOutputCol("bert-embedding")\
 .setMaxSentenceLength(512)\

# %%
train_data = bert_annotator.transform(train_data)

# %%
train_data.write.parquet('/content/drive/MyDrive/Priya/Spark-NLP/ner_dl_train.parquet')

# %%
#train_data.write.parquet('/content/drive/MyDrive/Priya/Spark-NLP/tinybert_train.parquet')

# %%
# Creating Pipeline using Glove_100d model
nerTagger = NerDLApproach()\
        .setInputCols(["sentence", "token","pos","bert-embedding"])\
        .setLabelColumn("label")\
        .setOutputCol("ner")\
        .setMaxEpochs(15)\
        .setLr(0.002)\
        .setPo(0.005)\
        .setDropout(0.5)\
        .setBatchSize(32)\
        .setRandomSeed(0)\
        .setVerbose(1)\
        .setValidationSplit(0.1)\
        .setUseContrib(True)\
        .setEvaluationLogExtended(True) \
        .setEnableOutputLogs(True)\
        .setIncludeConfidence(True)\
        .setOutputLogsPath('/content/drive/MyDrive/Priya/Spark-NLP/new_ner_logs_tiny-bert_128_3.0')\
        .setEnableMemoryOptimizer(True)\
        .setGraphFolder("/content/drive/MyDrive/Priya/Spark-NLP/tf-graph")
ner_pipeline_bert = Pipeline(stages=[
    nerTagger
])

# %%
# !cp -r /content/drive/MyDrive/Priya/Spark-NLP/ner_dl_train.parquet /content/

# %%
train_data = spark.read.parquet('/content/drive/MyDrive/Priya/Spark-NLP/tinybert_train.parquet')

# %%
#Training and Saving NER model
# %%time
ner_model_bert = ner_pipeline_bert.fit(train_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-5f67b31a1cf4> in <module>()
# ----> 1 get_ipython().run_cell_magic('time', '', 'ner_model_bert = ner_pipeline_bert.fit(train_data)')
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2115             magic_arg_s = self.var_expand(line, stack_depth)
#    2116             with self.builtin_trap:
# -> 2117                 result = fn(magic_arg_s, cell)
#    2118             return result
#    2119
#
# <decorator-gen-53> in time(self, line, cell, local_ns)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
# ...

# %%
ner_model_bert.stages[0].write().overwrite().save("/content/NER_AlBert_model_3.0")

# %%
ner_model_bert.stages[0].write().overwrite().save("/content/drive/MyDrive/Priya/Spark-NLP/NER_AlBert_3.0")

# %%
#Creating CoNLL(Conference on Natural Language Learning) files
from sparknlp.training import CoNLL

test_data = CoNLL().readDataset(spark, '/content/test.txt')
test_data.show(5)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-30746e33e329> in <module>()
#       1 #Creating CoNLL(Conference on Natural Language Learning) files
# ----> 2 from sparknlp.training import CoNLL
#       3
#       4 test_data = CoNLL().readDataset(spark, '/content/test.txt')
#       5 test_data.show(5)
#
# ModuleNotFoundError: No module named 'sparknlp'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
#test_data = bert_annotator.transform(test_data)
test_data = albert.transform(test_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-944921e1e092> in <module>()
#       1 #test_data = bert_annotator.transform(test_data)
# ----> 2 test_data = albert.transform(test_data)
#
# NameError: name 'albert' is not defined

# %%
predictions = ner_model_bert.transform(test_data)

# %%
#from sklearn.metrics import classification_report
import pyspark.sql.functions as F

preds = predictions.select(F.explode(F.arrays_zip('token.result','label.result','ner.result')).alias("cols")) \
        .select(F.col('cols.0').alias("token"),
        F.col('cols.1').alias("label"),
        F.col('cols.2').alias("ner"))

# %%
#Convert the Spark dataframe to a Pandas dataframe.
import pandas as pd
preds_df_dl =preds.toPandas()

# %%
print (classification_report(preds_df_dl['label'], preds_df_dl['ner']))

# %%
# !ls /content/NER_AlBert_model_3.0
# !zip -r NER_AlBert_model_3.0.zip /content/NER_AlBert_model_3.0
